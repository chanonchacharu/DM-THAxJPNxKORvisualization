# %% [markdown]
# # Thai X Japanese Drama: Can the challenge the global dominance of Korean Drama
#
# Midterm Project: Comprehensive Data Analysis and Visualization
#
# Duration: 2 weeks
# Submission Date: Sep. 28, 2023
#
# ### Requirements:
# 1. Select a Dataset:
# > - Choose a dataset that contains at least 500 entries and at least five different
# variables.
# 2. Data Exploration:
# > - Perform summary statistics to understand the basic metrics of each variable (mean, median, mode,
# variance, standard deviation).
# > - Identify any outliers and clean the dataset if necessary.
# 3. Statistical Analysis:
# > - Conduct hypothesis tests or other statistical methods to answer at least two questions you have
# about the dataset.
# > - Use measures of similarity, probability, and distributions to draw inferences from the data.
# 4. Data Visualization:
# > - Create at least four different types of visualizations using the dataset.
# > - These can be bar charts, line charts, scater plots, pie charts, etc., as appropriate for your data.
# 5. Interpretation:
# > - Prepare a presentation that walks through your exploratory data analysis, statistical findings, and
# visualizations.
# > - The presentation should be both factually accurate and easily understandable, targeted at an
# audience unfamiliar with your dataset.
# 6. Documentation:
# > - Alongside the presentation, prepare a report documenting your methodology, the statistical tests
# performed, the visualizations created, and your interpretations.
#
#
# ### Deliverables:
#
# 1. Cleaned and processed dataset in CSV format.
# 2. A presentation (PPT or equivalent) summarizing your findings for 7 minutes presentation.
# 3. A detailed report (Word, PDF, or equivalent).
#
# Evaluation Criteria:
# - Quality of data exploration and statistical analysis.
# - Effectiveness and appropriateness of data visualizations.
# - Coherence and clarity in the presentation and report.
# - Ability to interpret the results and draw meaningful conclusions.
#
# <br>
# Submission:
# Submit all the project files via Google Classroom.

# %% [markdown]
# # Statistical Analysis
#
# ### TODO:
# > * Statistical Analysis:
# >> * Conduct hypothesis tests or other statistical methods to answer at least two questions you have about the dataset.
# >> * Use measures of similarity, probability, and distributions to draw inferences from the data.
#
# ### Questions
# 1. Is there satistically significicant evidence that the average overall score given the Korean Drama by contriburos on MyDramaList website is higher than that of Thai and Japanese Drama?
# * Dive into more specific geners like Romantic, Horror, and others (focusing on that different region is know for)
# > * For example, Thailand is known for Horror movie, we might investigate whether people find Thai Horror Drama higher quality (via rating) than Korea (Japan?)

# %%
import pandas as pd
import numpy as np
import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/thai-and-japanese-drama-vs-korean-drama-dominance/tha_tha_actors.csv
# /kaggle/input/thai-and-japanese-drama-vs-korean-drama-dominance/jap_drama.csv
# /kaggle/input/thai-and-japanese-drama-vs-korean-drama-dominance/kor_user_reviews.csv
# /kaggle/input/thai-and-japanese-drama-vs-korean-drama-dominance/kor_kor_actors.csv
# /kaggle/input/thai-and-japanese-drama-vs-korean-drama-dominance/kor_drama.csv
# /kaggle/input/thai-and-japanese-drama-vs-korean-drama-dominance/tha_user_reviews.csv
# /kaggle/input/thai-and-japanese-drama-vs-korean-drama-dominance/jap_user_reviews.csv
# /kaggle/input/thai-and-japanese-drama-vs-korean-drama-dominance/jap_jap_actors.csv
# /kaggle/input/thai-and-japanese-drama-vs-korean-drama-dominance/tha_drama.csv

# %% [markdown]
# # Drama

# %%
# Load the data: ignoring drama_id, rank, and pop(ularity) because we won't be using the website ranking system
dtha_df = pd.read_csv('/kaggle/input/thai-and-japanese-drama-vs-korean-drama-dominance/tha_drama.csv').iloc[:,1:-2]
dkor_df = pd.read_csv('/kaggle/input/thai-and-japanese-drama-vs-korean-drama-dominance/kor_drama.csv').iloc[:,1:-2]
djap_df = pd.read_csv('/kaggle/input/thai-and-japanese-drama-vs-korean-drama-dominance/jap_drama.csv').iloc[:,1:-2]

# %% [markdown]
# # Reviews

# %%
rtha_df = pd.read_csv('/kaggle/input/thai-and-japanese-drama-vs-korean-drama-dominance/tha_user_reviews.csv').iloc[:,1:]
rkor_df = pd.read_csv('/kaggle/input/thai-and-japanese-drama-vs-korean-drama-dominance/kor_user_reviews.csv').iloc[:,1:]
rjap_df = pd.read_csv('/kaggle/input/thai-and-japanese-drama-vs-korean-drama-dominance/jap_user_reviews.csv').iloc[:,1:]

# %%
rtha_df.head()
# Out:
#              title  story  acting_cast  music  rewatch_value  overall  \
# 0              Her    6.0          8.0    9.0            5.0      7.0
# 1   Love in a Cage   10.0         10.0    7.0           10.0     10.0
# 2  The Cupid Coach    1.0          6.0    6.0            1.0      3.0
# 3         La Pluie    9.5          8.5    9.0            8.0      9.0
# 4   Love by Chance    4.0          8.5    9.0            1.0      5.5
#
#                                                 text              ep_watched  \
# 0  Contrived plot aside, the actors are terribly ...    4 of 4 episodes seen
# 1  Captivating from beginning to the end - the sy...   8 of 16 episodes seen
# 2  Content warning: youll want to claw your eyes ...  12 of 12 episodes seen
# 3  There are many Fantasy dramas out there but wh...  12 of 12 episodes seen
# 4  This drama was a bit of a mixed bag for me. Th...  14 of 14 episodes seen
#
#    n_helpful
# 0          3
# 1          1
# 2          4
# 3         13
# 4          0

# %% [markdown]
# # Utility Functions
#
# 2. Data Exploration:
# > - Perform summary statistics to understand the basic metrics of each variable (mean, median, mode,
# variance, standard deviation).
# > - Identify any outliers and clean the dataset if necessary.

# %%
from collections import Counter
import pandas as pd
import numpy as np

from scipy import stats
from typing import Tuple
import json


class DataAnalysisUtility:
    
    def calculate_statistics(
        self, 
        df: pd.DataFrame, 
        column_name: str
    ) -> dict:
        
        mean = df[column_name].mean()
        median = df[column_name].median()
        
        # Mode
        value_counter = Counter(df[column_name])
        nmax_occurance = value_counter.most_common(n=1)[0][1]
        mode = [key for key,val in value_counter.items() if val == nmax_occurance]
        
        variance = df[column_name].var()
        std_deviation = df[column_name].std()
        
        minimum = df[column_name].min()
        maximum = df[column_name].max()
        data_range = abs(maximum - minimum)
        
        statistics_dict = {
            'mean': mean,
            'median': median,
            'mode': mode,
            'variance': variance,
            'standard_deviation': std_deviation,
            'min': minimum,
            'max': maximum,
            'range': data_range
        }
        
        return statistics_dict
    
    def iqr_outlier_detector(
        self,
        df: pd.DataFrame, 
        column_name: str
    ) -> Tuple[pd.Series, pd.DataFrame]:
        q1 = df[column_name].quantile(0.25)
        q3 = df[column_name].quantile(0.75)
        iqr = q3 - q1

        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr
        # print(f'Boundaries: {lower_bound=} and {upper_bound=}')

        outlier_mask = ((df[column_name] < lower_bound) | (df[column_name] > upper_bound))
        df_no_outliers = df[~outlier_mask]

        return outlier_mask, df_no_outliers

    def zscore_outlier_detector(
        self,
        df: pd.DataFrame, 
        column_name: str, 
        threshold=3
    ) -> Tuple[pd.Series, pd.DataFrame]:
        z_scores = np.abs(stats.zscore(df[column_name]))
        outlier_mask = z_scores > threshold
        df_no_outliers = df[~outlier_mask]

        return outlier_mask, df_no_outliers

# %%
# Testing the utility functions for processing the data
util = DataAnalysisUtility()  

result_a = util.calculate_statistics(rtha_df,'overall')
print(json.dumps(result_a,indent=3),end='\n\n')

# Test Outlier Detection Function
outlier_mask, no_outlier_df = util.zscore_outlier_detector(rtha_df, column_name='overall')
print(no_outlier_df.shape, rtha_df.shape)

a,b = util.iqr_outlier_detector(rtha_df, 'overall')
print(b.shape, rtha_df.shape)
# Out:
# {
#    "mean": 7.999333826794967,
#    "median": 9.0,
#    "mode": [
#       10.0
#    ],
#    "variance": 5.754848534530734,
#    "standard_deviation": 2.3989265379604134,
#    "min": 1.0,
#    "max": 10.0,
#    "range": 9.0
# }
#
# (6755, 9) (6755, 9)
# (6448, 9) (6755, 9)

# %% [markdown]
# # TODO: Drama Observation

# %%
# If we're putting the emphasis on Drama only, then we have to do filtering
dkor_df = pd.read_csv('/kaggle/input/thai-and-japanese-drama-vs-korean-drama-dominance/kor_drama.csv').iloc[:,1:-2]
dkor_df = dkor_df[dkor_df['type'] == 'Drama']
# dkor_df['genres'][0].split(',  ')

def split_geners_tags(df: pd.DataFrame) -> pd.DataFrame:
    df['genres'] = df['genres'].apply(lambda x: [char.replace(',','').strip() for char in str(x).split()])
    df['tags'] = df['tags'].apply(lambda x: [char.replace(',','').strip()  for char in str(x).split()])
    return df

def custom_rating_generator(df: pd.DataFrame) -> pd.DataFrame:
    df['watched_ratio'] = df['tot_num_user'] / df['tot_watched']
    df['watched_ratio'] = df['watched_ratio'].apply(lambda x: round(x,3))
    df['scored_signif'] = df['tot_user_score'] * df['watched_ratio']
    return df

dkor_df = split_geners_tags(dkor_df)
dkor_df = custom_rating_generator(dkor_df)
dkor_df.head()
# Out:
#                                     drama_name    native_name  year  \
# 0                                    Mask Girl           마스크걸  2023
# 1                                Better Things  Better Things  2023
# 2                                   My Dearest             연인  2023
# 3                                Sing My Crush           따라바람  2023
# 4  The Uncanny Counter Season 2: Counter Punch         카운터 펀치  2023
#
#                                             synopsis  \
# 0  Kim Mo Mi is an ordinary office woman with a s...
# 1  Comprised of 3 episodes, the sitcom follows th...
# 2  A love-story between a noblewoman and a myster...
# 3  After a disastrous first encounter between Ba ...
# 4  Evil spirits from the afterlife arrive on Eart...
#
#                                     genres  \
# 0       [Thriller, Mystery, Comedy, Drama]
# 1                                 [Sitcom]
# 2  [Historical, Romance, Drama, Melodrama]
# 3          [Music, Comedy, Romance, Youth]
# 4  [Action, Mystery, Comedy, Supernatural]
#
#                                                 tags  \
# 0  [Noir, Revenge, Suspense, Inferiority, Complex...
# 1   [Short, Length, Series, Miniseries, Web, Series]
# 2  [Joseon, Dynasty, Qing, Invasion, Of, Joseon, ...
# 3  [LGBTQ+, Band, High, School, To, Working, Life...
# 4  [Dark, Fantasy, Fantasy, Evil, Spirit, Drama, ...
#
#                             director                     sc_writer  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2  ['Kim Sung Yong', 'Lee Han Joon']           ['Hwang Jin Young']
# 3                   ['So Joon Moon']                           NaN
# 4                  ['Yoo Seon Dong']  ['Kim Sae Bom', 'Yeo Ji Na']
#
#        country   type  ...    start_dt      end_dt                   aired_on  \
# 0  South Korea  Drama  ...  2023-08-18  2023-08-18                     Friday
# 1  South Korea  Drama  ...  2023-08-07  2023-08-11  Monday, Wednesday, Friday
# 2  South Korea  Drama  ...  2023-08-04  2023-09-02           Friday, Saturday
# 3  South Korea  Drama  ...  2023-08-02  2023-08-02                  Wednesday
# 4  South Korea  Drama  ...  2023-07-29  2023-09-03           Saturday, Sunday
#
#            org_net tot_user_score tot_num_user  tot_watched  \
# 0          Netflix            7.9       5814.0        13098
# 1              NaN            8.0         16.0           44
# 2              MBC            8.7       1680.0         8523
# 3              NaN            8.1       3613.0         8224
# 4  Netflix OCN tvN            8.5       5542.0        27408
#
#                               content_rt  watched_ratio scored_signif
# 0  18+ Restricted (violence & profanity)          0.444        3.5076
# 1                          Not Yet Rated          0.364        2.9120
# 2                15+ - Teens 15 or older          0.197        1.7139
# 3                          Not Yet Rated          0.439        3.5559
# 4                15+ - Teens 15 or older          0.202        1.7170
#
# [5 rows x 22 columns]

# %% [markdown]
# # TODO: Data Visualization and Analysis

# %%
# TODO: Add Weighted Rating based on the number of people that found the review useful
def review_score_pipeline(
    df: pd.DataFrame,
    features: list = [],
) -> pd.DataFrame:
    
    df['ep_watched'] = df['ep_watched'].fillna('0 of 0 episodes seen')
    df['tot_watched'] = df['ep_watched'].apply(lambda x: int(str(x).split(' ')[0]))
    df['tot_ep'] = df['ep_watched'].apply(lambda x: int(str(x).split(' ')[2]))
    df['watched_ratio'] = df['tot_watched'] / df['tot_ep']
    df['watched_ratio'] = df['watched_ratio'].fillna(0.0).apply(lambda x: round(x,3))
    
    # TODO: Weighted Score Rating --> df['weigthed_signif'] 
    
    return df if len(features) == 0 else df[features]

def process_review_text(text: str) -> list:
    # TODO: Tokenization, StopwordRemovers, etc.
    pass

def outlier_detection_marker():
    pass

# %%
features = ['title','story','acting_cast','music','rewatch_value','overall','text','n_helpful','tot_watched','tot_ep','watched_ratio']

rtha_df = review_score_pipeline(rtha_df, features)
rkor_df = review_score_pipeline(rkor_df, features)
rjap_df = review_score_pipeline(rjap_df, features)

# %%
rtha_df.head()
# Out:
#              title  story  acting_cast  music  rewatch_value  overall  \
# 0              Her    6.0          8.0    9.0            5.0      7.0
# 1   Love in a Cage   10.0         10.0    7.0           10.0     10.0
# 2  The Cupid Coach    1.0          6.0    6.0            1.0      3.0
# 3         La Pluie    9.5          8.5    9.0            8.0      9.0
# 4   Love by Chance    4.0          8.5    9.0            1.0      5.5
#
#                                                 text  n_helpful  tot_watched  \
# 0  Contrived plot aside, the actors are terribly ...          3            4
# 1  Captivating from beginning to the end - the sy...          1            8
# 2  Content warning: youll want to claw your eyes ...          4           12
# 3  There are many Fantasy dramas out there but wh...         13           12
# 4  This drama was a bit of a mixed bag for me. Th...          0           14
#
#    tot_ep  watched_ratio
# 0       4            1.0
# 1      16            0.5
# 2      12            1.0
# 3      12            1.0
# 4      14            1.0

# %%
rkor_df.head()
# Out:
#                       title  story  acting_cast  music  rewatch_value  \
# 0       The Good Bad Mother   10.0         10.0    8.0            8.0
# 1                 Mask Girl    9.0         10.0    8.5            8.0
# 2  Lies Hidden in My Garden    9.5         10.0    9.5            9.0
# 3                 Mask Girl   10.0         10.0   10.0            9.0
# 4                         W    8.5          8.0    5.0            8.0
#
#    overall                                               text  n_helpful  \
# 0     10.0  Watching this drama was an incredibly fulfilli...         27
# 1      9.0  Warning ahead: This is no show for softies. An...         27
# 2      9.5  Absolutely fantastic slow burn dark psychologi...         10
# 3     10.0  The retro style of the beginning and the calmi...         10
# 4      8.5  Overall 8.5    Story 8.5 Acting/Cast 8.0 Music...          1
#
#    tot_watched  tot_ep  watched_ratio
# 0           14      14            1.0
# 1            7       7            1.0
# 2            8       8            1.0
# 3            7       7            1.0
# 4           16      16            1.0

# %%
rjap_df.head()
# Out:
#                   title  story  acting_cast  music  rewatch_value  overall  \
# 0  Nihon Boro Yado Kiko    5.0          9.0    9.0            1.0      6.5
# 1             One Piece   10.0         10.0    8.5            9.5     10.0
# 2        Kieta Hatsukoi   10.0         10.0   10.0           10.0     10.0
# 3             One Piece   10.0         10.0    9.0           10.0     10.0
# 4             One Piece    9.0          8.0    8.0            8.5      8.5
#
#                                                 text  n_helpful  tot_watched  \
# 0  It was cute, it was charming, it had its spunk...          3           12
# 1  Wow! This live-action series really justifies ...         14            8
# 2  The Kieta Hatsukoi live action changed the tra...          0           10
# 3  I am a One Piece fan and also have also grown ...          7            8
# 4  Finished this and still not sure if it was the...          3            8
#
#    tot_ep  watched_ratio
# 0      12            1.0
# 1       8            1.0
# 2      10            1.0
# 3       8            1.0
# 4       8            1.0

# %%
# There are some wired cases where the tot_watched is greater than tot_ep
# It is possible that the reviewers rewatched the drama multiple times
# set(rtha_df['watched_ratio'].tolist())
rtha_df[rtha_df['watched_ratio'] > 1.0]
# Out:
#                                          title  story  acting_cast  music  \
# 379                            Midnight Museum   10.0         10.0   10.0
# 380                            Midnight Museum   10.0         10.0    9.0
# 384                            Midnight Museum   10.0         10.0   10.0
# 481                                Tin Tem Jai    5.5          5.0    6.5
# 2270                           Are We Alright?   10.0          9.5    9.5
# 3153                                  Why R U?    9.5          9.5    8.0
# 3347                                  Praomook   10.0         10.0    8.5
# 4013  Club Friday to Be Continued: She Changed    4.5          5.0    5.0
# 4401                         My Name Is Busaba    9.0          9.0    6.0
# 4419                              Unlucky Ploy    1.0          1.0    2.5
# 4599                En of Love: Love Mechanics    8.5          9.0    7.5
# 5040                       Until We Meet Again   10.0         10.0   10.0
# 6262  Club Friday to Be Continued: She Changed    8.5          9.0    8.5
# 6272                      Club Friday Season 8    9.5          9.5    9.5
#
#       rewatch_value  overall  \
# 379            10.0     10.0
# 380            10.0     10.0
# 384            10.0     10.0
# 481             4.5      5.0
# 2270           10.0     10.0
# 3153            9.0     10.0
# 3347           10.0     10.0
# 4013            1.0      6.0
# 4401            9.5      8.5
# 4419            1.0      1.0
# 4599            7.0      8.0
# 5040           10.0     10.0
# 6262            7.0      8.5
# 6272            9.5      9.5
#
#                                                    text  n_helpful  \
# 379   This is my first time writing a review for a s...         14
# 380   this series has honestly blown me away and we ...         10
# 384   I Love this series. Love the mystery and the c...          2
# 481   I swear if Tin doesnt realise how good the sen...          4
# 2270  Overall 10    Story 10 Acting/Cast 9.5 Music 9...          5
# 3153  Overall 10    Story 9.5 Acting/Cast 9.5 Music ...         39
# 3347  I love this series, I love the actors, there i...         25
# 4013  Overall 6.0    Story 4.5 Acting/Cast 5.0 Music...          6
# 4401  I started watching this show for the food. It ...          7
# 4419  worst quality and story.  It is time to think ...          1
# 4599  Overall 8.0    Story 8.5 Acting/Cast 9.0 Music...         30
# 5040  This is the only series i cried alot and this ...         31
# 6262  Saw this on netflix last week, have to say I r...          1
# 6272  love the casts..\r\nthey acted very soulful......          6
#
#       tot_watched  tot_ep  watched_ratio
# 379            15      10          1.500
# 380            15      10          1.500
# 384            15      10          1.500
# 481            12      10          1.200
# 2270           20      15          1.333
# 3153           14      13          1.077
# 3347           17      15          1.133
# 4013           22      13          1.692
# 4401           24      16          1.500
# 4419           20      16          1.250
# 4599            6       4          1.500
# 5040           18      17          1.059
# 6262           22      13          1.692
# 6272           41      39          1.051

# %% [markdown]
# # Statistical Analysis
#
# 3. Statistical Analysis:
# > - Conduct hypothesis tests or other statistical methods to answer at least two questions you have
# about the dataset.
# > - Use measures of similarity, probability, and distributions to draw inferences from the data.
#
# <br>
#
# ----
#
# ### Hypothesis:
# #### 1. Is there a significant difference in the average viewer ratings of drama TV shows among these three countries?
# * Statistical Method: Analysis of Variance (ANOVA)**
#
# * Hypothesis:
#
# > * Null Hypothesis (H0):
# >> The average viewer ratings of drama TV shows are equal across all three countries (Thailand, Japan, and Korea).
# > * Alternative Hypothesis (Ha):
# >> The average viewer ratings of drama TV shows are not equal across at least one pair of countries.
#
# *  Procedure:
# Collect viewer rating data for drama TV shows from the three countries. erform an ANOVA test to compare the means of viewer ratings among the three groups (countries). f the ANOVA test results in a significant p-value, conduct post-hoc tests (e.g., Tukey's HSD) to identify which specific pairs of countries have significantly different viewer ratings.
#
#
# #### 2. What is the most popular geners of drama from each countires (Thailand, Japan, and Korea)? How do they compare with other countires
# * Ex. Thailand is popular with Horror, so does Thai Horror Drama receives better rathing than Japanese and Korean Drama under Horror gener?
# * How do we detemined which genere is the most popular for each country
# > * Metrics or Measurements for Genres popularity??:

# %%
kor_genres_dict = {}
dkor_df['tot_user_score'] = dkor_df['tot_user_score'].fillna(dkor_df['tot_user_score'].mean())

for index, row in dkor_df.iterrows():
    genres = row['genres']
    for genre in genres:
        if genre not in kor_genres_dict.keys():
            kor_genres_dict[genre] = {
                'num': 1,
                'score': [row['tot_user_score']]
            }
        else:
            kor_genres_dict[genre]['num'] += 1
            kor_genres_dict[genre]['score'].append(row['tot_user_score'])

for key, val in kor_genres_dict.items():
    genre_average = sum(val['score']) / len(val['score'])
    kor_genres_dict[key]['score'] = genre_average
        
kor_genres_dict
# Out:
# {'Thriller': {'num': 231, 'score': 7.970019958883202},
#  'Mystery': {'num': 312, 'score': 7.903444264429552},
#  'Comedy': {'num': 677, 'score': 7.5985182924906445},
#  'Drama': {'num': 875, 'score': 7.637054026873312},
#  'Sitcom': {'num': 26, 'score': 7.544200807847665},
#  'Historical': {'num': 79, 'score': 7.975949367088609},
#  'Romance': {'num': 1135, 'score': 7.511207678874213},
#  'Melodrama': {'num': 234, 'score': 7.622113720094097},
#  'Music': {'num': 57, 'score': 7.496491228070172},
#  'Youth': {'num': 351, 'score': 7.461746588347859},
#  'Action': {'num': 119, 'score': 8.058610172285876},
#  'Supernatural': {'num': 113, 'score': 7.548672566371682},
#  'Military': {'num': 8, 'score': 8.4},
#  'Fantasy': {'num': 162, 'score': 7.653703703703702},
#  'Horror': {'num': 42, 'score': 7.752380952380954},
#  'Psychological': {'num': 53, 'score': 7.967924528301884},
#  'Life': {'num': 304, 'score': 7.72006066450026},
#  'Crime': {'num': 55, 'score': 8.024992918218539},
#  'Food': {'num': 52, 'score': 7.344230769230771},
#  'Adventure': {'num': 18, 'score': 7.748589472334422},
#  'Sci-Fi': {'num': 56, 'score': 7.6607142857142865},
#  'Business': {'num': 97, 'score': 7.588136299010715},
#  'Medical': {'num': 44, 'score': 8.011363636363638},
#  'Family': {'num': 84, 'score': 7.269935839309759},
#  'Political': {'num': 51, 'score': 7.966168833372934},
#  'Law': {'num': 69, 'score': 8.036231884057973},
#  'Mature': {'num': 2, 'score': 7.6000000000000005},
#  'Sports': {'num': 24, 'score': 7.716666666666668},
#  'nan': {'num': 5, 'score': 6.494922100403923},
#  'Documentary': {'num': 5, 'score': 7.859999999999999},
#  'Martial': {'num': 2, 'score': 6.25},
#  'Arts': {'num': 2, 'score': 6.25},
#  'Tokusatsu': {'num': 5, 'score': 7.220000000000001},
#  'War': {'num': 1, 'score': 8.3}}

# %%
# dkor_df is preprocess data
kor_genres_dict = Counter(genre for genres in dkor_df['genres'] for genre in genres)
skor_genres_dict = sorted(kor_genres_dict.items(), key=lambda x: x[1], reverse=True)
top_five_genres = dict(skor_genres_dict[:5])

skor_genres_dict = dict(skor_genres_dict)

print(f'{top_five_genres=}',end='\n\n')

print(f'Complete Genres list: {json.dumps(skor_genres_dict,indent=4)}')
# Out:
# top_five_genres={'Romance': 1135, 'Drama': 875, 'Comedy': 677, 'Youth': 351, 'Mystery': 312}
#
# Complete Genres list: {
#     "Romance": 1135,
#     "Drama": 875,
#     "Comedy": 677,
#     "Youth": 351,
#     "Mystery": 312,
#     "Life": 304,
#     "Melodrama": 234,
#     "Thriller": 231,
#     "Fantasy": 162,
#     "Action": 119,
#     "Supernatural": 113,
#     "Business": 97,
#     "Family": 84,
#     "Historical": 79,
#     "Law": 69,
#     "Music": 57,
#     "Sci-Fi": 56,
#     "Crime": 55,
#     "Psychological": 53,
#     "Food": 52,
#     "Political": 51,
#     "Medical": 44,
#     "Horror": 42,
#     "Sitcom": 26,
#     "Sports": 24,
#     "Adventure": 18,
#     "Military": 8,
#     "nan": 5,
#     "Documentary": 5,
#     "Tokusatsu": 5,
#     "Mature": 2,
#     "Martial": 2,
#     "Arts": 2,
#     "War": 1
# }

# %%
# Explore with different group style?
dkor_df_test = pd.read_csv('/kaggle/input/thai-and-japanese-drama-vs-korean-drama-dominance/kor_drama.csv').iloc[:,1:-2]
Counter(dkor_df_test['genres'])
# Out:
# Counter({'Romance': 81,
#          'Comedy,  Romance': 52,
#          'Romance,  Youth': 52,
#          'Comedy,  Romance,  Drama': 51,
#          'Romance,  Drama': 50,
#          'Romance,  Drama,  Melodrama': 38,
#          'Romance,  Youth,  Drama': 36,
#          'Comedy,  Romance,  Life,  Drama': 35,
#          'Comedy,  Romance,  Youth': 28,
#          'Drama': 27,
#          'Comedy,  Romance,  Youth,  Drama': 24,
#          'Romance,  Drama,  Family,  Melodrama': 22,
#          'Comedy': 20,
#          'Romance,  Life,  Youth,  Drama': 19,
#          'Comedy,  Romance,  Drama,  Fantasy': 18,
#          'Comedy,  Romance,  Life': 17,
#          'Life,  Youth': 17,
#          'Comedy,  Romance,  Fantasy': 16,
#          'Romance,  Life,  Drama': 16,
#          'Business,  Comedy,  Romance,  Drama': 16,
#          'Thriller,  Mystery,  Drama': 15,
#          'Romance,  Life,  Drama,  Melodrama': 15,
#          'Action,  Thriller,  Mystery,  Drama': 14,
#          'Youth,  Drama': 14,
#          'Comedy,  Romance,  Life,  Youth': 14,
#          'Romance,  Life,  Youth': 14,
#          'Romance,  Life': 12,
#          'Comedy,  Life,  Drama': 12,
#          'Comedy,  Life': 12,
#          'Life,  Drama': 10,
#          'Thriller,  Mystery,  Psychological,  Drama': 9,
#          'Action,  Thriller,  Mystery,  Crime': 9,
#          'Comedy,  Drama': 9,
#          'Life': 9,
#          'Thriller,  Mystery,  Romance,  Drama': 8,
#          'Romance,  Drama,  Fantasy': 8,
#          'Comedy,  Romance,  Drama,  Melodrama': 8,
#          'Comedy,  Romance,  Drama,  Supernatural': 8,
#          'Thriller,  Mystery,  Horror,  Supernatural': 7,
#          'Thriller,  Mystery': 7,
#          'Comedy,  Youth': 7,
#          'Drama,  Family,  Melodrama': 7,
#          'Mystery,  Drama': 6,
#          'Business,  Romance': 6,
#          'Horror,  Comedy,  Romance,  Supernatural': 6,
#          'Comedy,  Sitcom': 6,
#          'Thriller,  Mystery,  Law,  Drama': 6,
#          'Music,  Romance,  Youth': 6,
#          'Drama,  Family': 6,
#          'Historical,  Comedy,  Romance,  Drama': 6,
#          'Comedy,  Romance,  Drama,  Sitcom': 6,
#          'Mystery,  Comedy,  Romance,  Drama': 5,
#          'Business,  Romance,  Drama,  Melodrama': 5,
#          'Mystery,  Comedy': 5,
#          'Thriller,  Mystery,  Supernatural': 5,
#          'Romance,  Fantasy': 5,
#          'Mystery,  Romance,  Youth,  Drama': 5,
#          nan: 5,
#          'Business,  Comedy,  Romance': 5,
#          'Business,  Comedy,  Life,  Drama': 5,
#          'Youth': 5,
#          'Romance,  Youth,  Drama,  Melodrama': 5,
#          'Psychological,  Comedy,  Romance,  Drama': 5,
#          'Romance,  Drama,  Family': 5,
#          'Comedy,  Romance,  Drama,  Medical': 5,
#          'Business,  Comedy,  Romance,  Melodrama': 5,
#          'Romance,  Drama,  Medical': 4,
#          'Thriller,  Mystery,  Drama,  Melodrama': 4,
#          'Action,  Thriller,  Drama,  Sci-Fi': 4,
#          'Thriller,  Mystery,  Crime,  Drama': 4,
#          'Thriller,  Romance,  Drama,  Melodrama': 4,
#          'Food,  Comedy,  Romance': 4,
#          'Comedy,  Law,  Romance': 4,
#          'Business,  Comedy,  Romance,  Life': 4,
#          'Comedy,  Romance,  Youth,  Fantasy': 4,
#          'Romance,  Youth,  Fantasy': 4,
#          'Comedy,  Romance,  Family': 4,
#          'Mystery,  Law,  Drama': 4,
#          'Mystery,  Comedy,  Romance,  Fantasy': 4,
#          'Thriller,  Drama': 4,
#          'Romance,  Life,  Drama,  Medical': 4,
#          'Action,  Thriller,  Mystery,  Comedy': 4,
#          'Comedy,  Romance,  Family,  Melodrama': 4,
#          'Comedy,  Drama,  Melodrama': 4,
#          'Music,  Romance,  Youth,  Drama': 4,
#          'Comedy,  Romance,  Drama,  Family': 4,
#          'Comedy,  Romance,  Fantasy,  Melodrama': 4,
#          'Food': 4,
#          'Thriller,  Mystery,  Sci-Fi': 4,
#          'Historical,  Romance,  Fantasy,  Political': 4,
#          'Comedy,  Romance,  Youth,  Sports': 4,
#          'Historical,  Romance,  Drama,  Melodrama': 3,
#          'Food,  Life,  Drama': 3,
#          'Business,  Drama,  Political': 3,
#          'Comedy,  Romance,  Life,  Melodrama': 3,
#          'Psychological,  Romance,  Youth,  Drama': 3,
#          'Mystery,  Comedy,  Romance,  Supernatural': 3,
#          'Thriller,  Mystery,  Comedy,  Romance': 3,
#          'Historical,  Mystery,  Comedy,  Romance': 3,
#          'Thriller,  Mystery,  Comedy,  Fantasy': 3,
#          'Romance,  Life,  Drama,  Family': 3,
#          'Music,  Romance': 3,
#          'Political': 3,
#          'Mystery,  Comedy,  Romance,  Youth': 3,
#          'Comedy,  Life,  Youth,  Drama': 3,
#          'Law,  Romance,  Life,  Drama': 3,
#          'Comedy,  Romance,  Fantasy,  Supernatural': 3,
#          'Historical,  Drama': 3,
#          'Historical,  Drama,  Political': 3,
#          'Thriller,  Romance,  Drama': 3,
#          'Romance,  Youth,  Supernatural': 3,
#          'Action,  Thriller,  Mystery,  Sci-Fi': 3,
#          'Historical,  Romance,  Fantasy': 3,
#          'Action,  Historical,  Comedy,  Romance': 3,
#          'Romance,  Drama,  Melodrama,  Political': 3,
#          'Thriller,  Mystery,  Drama,  Fantasy': 3,
#          'Mystery,  Romance': 3,
#          'Music,  Youth,  Drama': 3,
#          'Food,  Romance': 3,
#          'Life,  Drama,  Melodrama': 3,
#          'Comedy,  Romance,  Youth,  Melodrama': 3,
#          'Comedy,  Romance,  Supernatural': 3,
#          'Music,  Comedy,  Romance': 3,
#          'Food,  Comedy,  Romance,  Life': 3,
#          'Action,  Mystery,  Comedy,  Drama': 3,
#          'Action,  Mystery,  Comedy,  Crime': 3,
#          'Action,  Thriller,  Mystery,  Supernatural': 3,
#          'Business,  Romance,  Life,  Drama': 3,
#          'Youth,  Supernatural': 3,
#          'Business,  Comedy,  Drama': 3,
#          'Thriller,  Mystery,  Romance,  Melodrama': 3,
#          'Comedy,  Romance,  Melodrama,  Supernatural': 3,
#          'Food,  Adventure,  Romance': 3,
#          'Thriller,  Mystery,  Psychological': 3,
#          'Comedy,  Law,  Romance,  Drama': 3,
#          'Comedy,  Romance,  Melodrama': 3,
#          'Romance,  Melodrama': 3,
#          'Food,  Comedy,  Romance,  Drama': 3,
#          'Historical,  Romance,  Drama,  Political': 3,
#          'Romance,  Family,  Melodrama': 3,
#          'Music,  Comedy,  Romance,  Youth': 2,
#          'Action,  Military,  Drama': 2,
#          'Action,  Thriller,  Crime,  Drama': 2,
#          'Comedy,  Crime,  Drama': 2,
#          'Mystery,  Romance,  Drama,  Sci-Fi': 2,
#          'Historical,  Mystery,  Romance,  Drama': 2,
#          'Thriller,  Drama,  Melodrama': 2,
#          'Law,  Drama': 2,
#          'Action,  Thriller,  Horror,  Fantasy': 2,
#          'Action,  Crime,  Drama': 2,
#          'Comedy,  Youth,  Drama': 2,
#          'Historical,  Mystery,  Romance,  Medical': 2,
#          'Action,  Historical,  Romance,  Fantasy': 2,
#          'Business,  Comedy': 2,
#          'Action,  Youth,  Drama': 2,
#          'Romance,  Youth,  Melodrama': 2,
#          'Mystery,  Romance,  Drama,  Supernatural': 2,
#          'Music,  Documentary': 2,
#          'Law,  Drama,  Melodrama': 2,
#          'Action,  Thriller,  Crime': 2,
#          'Mystery,  Drama,  Melodrama': 2,
#          'Mystery,  Romance,  Fantasy,  Melodrama': 2,
#          'Mystery,  Romance,  Drama,  Fantasy': 2,
#          'Food,  Romance,  Drama': 2,
#          'Action,  Thriller,  Horror,  Sci-Fi': 2,
#          'Romance,  Sci-Fi': 2,
#          'Mystery,  Romance,  Drama,  Melodrama': 2,
#          'Family,  Melodrama': 2,
#          'Music,  Comedy,  Drama': 2,
#          'Business': 2,
#          'Mystery,  Horror,  Youth,  Supernatural': 2,
#          'Music,  Comedy,  Romance,  Drama': 2,
#          'Thriller,  Mystery,  Psychological,  Crime': 2,
#          'Horror': 2,
#          'Mystery,  Law,  Crime,  Drama': 2,
#          'Music': 2,
#          'Psychological,  Life,  Drama': 2,
#          'Thriller,  Comedy,  Romance,  Drama': 2,
#          'Music,  Romance,  Drama': 2,
#          'Comedy,  Romance,  Life,  Fantasy': 2,
#          'Life,  Youth,  Drama': 2,
#          'Comedy,  Fantasy': 2,
#          'Romance,  Life,  Drama,  Sports': 2,
#          'Mystery,  Romance,  Youth': 2,
#          'Comedy,  Romance,  Drama,  Sci-Fi': 2,
#          'Romance,  Youth,  Drama,  Fantasy': 2,
#          'Action,  Mystery,  Comedy,  Romance': 2,
#          'Comedy,  Romance,  Sitcom': 2,
#          'Romance,  Youth,  Sports': 2,
#          'Music,  Drama': 2,
#          'Food,  Business,  Comedy,  Romance': 2,
#          'Romance,  Drama,  Supernatural': 2,
#          'Historical,  Romance,  Drama,  Supernatural': 2,
#          'Thriller,  Sci-Fi': 2,
#          'Food,  Comedy,  Romance,  Melodrama': 2,
#          'Youth,  Drama,  Sports': 2,
#          'Food,  Comedy,  Romance,  Youth': 2,
#          'Mystery,  Business,  Romance,  Melodrama': 2,
#          'Mystery,  Horror,  Supernatural': 2,
#          'Music,  Mystery,  Comedy,  Romance': 2,
#          'Horror,  Comedy,  Romance,  Fantasy': 2,
#          'Thriller,  Mystery,  Drama,  Political': 2,
#          'Law,  Drama,  Political': 2,
#          'Romance,  Youth,  Sci-Fi': 2,
#          'Thriller,  Mystery,  Romance,  Supernatural': 2,
#          'Mystery,  Horror,  Romance,  Supernatural': 2,
#          'Mystery,  Comedy,  Law,  Drama': 2,
#          'Historical,  Romance,  Melodrama,  Political': 2,
#          'Comedy,  Family,  Sitcom': 2,
#          'Romance,  Life,  Drama,  Supernatural': 2,
#          'Music,  Comedy,  Life,  Youth': 2,
#          'Food,  Life': 2,
#          'Mystery,  Comedy,  Youth,  Drama': 2,
#          'Business,  Romance,  Family,  Melodrama': 2,
#          'Business,  Romance,  Drama': 2,
#          'Food,  Comedy,  Life,  Sitcom': 2,
#          'Comedy,  Romance,  Life,  Sports': 2,
#          'Thriller,  Mystery,  Law': 2,
#          'Comedy,  Life,  Youth': 2,
#          'Historical,  Romance,  Medical,  Fantasy': 2,
#          'Thriller,  Comedy,  Romance,  Fantasy': 2,
#          'Romance,  Drama,  Melodrama,  Supernatural': 2,
#          'Comedy,  Drama,  Family': 2,
#          'Thriller,  Comedy,  Law,  Romance': 2,
#          'Music,  Romance,  Drama,  Supernatural': 2,
#          'Romance,  Family': 2,
#          'Tokusatsu,  Sci-Fi': 2,
#          'Family': 2,
#          'Psychological,  Comedy,  Romance': 2,
#          'Action,  Comedy,  Romance,  Drama': 2,
#          'Thriller,  Mystery,  Comedy,  Drama': 1,
#          'Sitcom': 1,
#          'Action,  Mystery,  Comedy,  Supernatural': 1,
#          'Mystery,  Drama,  Fantasy,  Supernatural': 1,
#          'Romance,  Fantasy,  Melodrama': 1,
#          'Thriller,  Mystery,  Youth,  Drama': 1,
#          'Action,  Adventure,  Drama,  Sci-Fi': 1,
#          'Historical,  Horror,  Romance,  Fantasy': 1,
#          'Comedy,  Life,  Drama,  Family': 1,
#          'Music,  Supernatural': 1,
#          'Action,  Thriller,  Comedy,  Drama': 1,
#          'Action,  Comedy': 1,
#          'Comedy,  Life,  Drama,  Medical': 1,
#          'Action,  Adventure,  Mystery,  Comedy': 1,
#          'Historical,  Law,  Romance,  Drama': 1,
#          'Action,  Thriller,  Drama,  Melodrama': 1,
#          'Historical,  Romance,  Youth,  Drama': 1,
#          'Comedy,  Romance,  Medical,  Fantasy': 1,
#          'Law,  Romance,  Drama': 1,
#          'Business,  Life,  Drama': 1,
#          'Thriller,  Mystery,  Business,  Drama': 1,
#          'Romance,  Drama,  Mature': 1,
#          'Mystery,  Romance,  Melodrama,  Political': 1,
#          'Psychological,  Romance,  Youth': 1,
#          'Mystery,  Youth': 1,
#          'Comedy,  Youth,  Sports': 1,
#          'Thriller,  Comedy,  Youth,  Sci-Fi': 1,
#          'Business,  Drama,  Fantasy,  Political': 1,
#          'Thriller,  Mystery,  Psychological,  Mature': 1,
#          'Action,  Youth,  Fantasy': 1,
#          'Thriller,  Comedy,  Crime,  Drama': 1,
#          'Mystery,  Horror,  Life,  Supernatural': 1,
#          'Mystery,  Crime,  Drama': 1,
#          'Historical,  Comedy,  Drama,  Political': 1,
#          'Life,  Drama,  Sci-Fi,  Melodrama': 1,
#          'Thriller,  Mystery,  Comedy,  Sci-Fi': 1,
#          'Action,  Mystery,  Comedy,  Law': 1,
#          'Comedy,  Law,  Drama': 1,
#          'Psychological,  Drama,  Fantasy,  Supernatural': 1,
#          'Comedy,  Drama,  Sports': 1,
#          'Romance,  Sports': 1,
#          'Adventure': 1,
#          'Military,  Comedy': 1,
#          'Drama,  Sci-Fi': 1,
#          'Mystery,  Comedy,  Romance': 1,
#          'Action,  Thriller,  Romance,  Youth': 1,
#          'Action,  Thriller,  Law': 1,
#          'Mystery,  Law,  Romance,  Melodrama': 1,
#          'Thriller,  Law,  Drama,  Medical': 1,
#          'Mystery': 1,
#          'Drama,  Melodrama': 1,
#          'Music,  Psychological,  Drama,  Fantasy': 1,
#          'Thriller,  Mystery,  Fantasy,  Supernatural': 1,
#          'Thriller,  Mystery,  Comedy': 1,
#          'Romance,  Drama,  Sports,  Melodrama': 1,
#          'Music,  Comedy,  Life,  Drama': 1,
#          'Business,  Life,  Youth,  Drama': 1,
#          'Mystery,  Law,  Drama,  Fantasy': 1,
#          'Action,  Thriller,  Drama,  Fantasy': 1,
#          'Drama,  Medical': 1,
#          'Crime,  Youth,  Drama': 1,
#          'Romance,  Youth,  Martial Arts,  Sports': 1,
#          'Action,  Military,  Mystery,  Law': 1,
#          'Food,  Family': 1,
#          'Thriller,  Mystery,  Romance,  Youth': 1,
#          'Comedy,  Medical': 1,
#          'Comedy,  Medical,  Fantasy,  Supernatural': 1,
#          'Crime': 1,
#          'Thriller,  Mystery,  Horror,  Sci-Fi': 1,
#          'Thriller,  Psychological,  Youth': 1,
#          'Romance,  Youth,  Sports,  Fantasy': 1,
#          'Thriller,  Historical,  Drama,  Political': 1,
#          'Food,  Romance,  Life': 1,
#          'Thriller,  Mystery,  Law,  Crime': 1,
#          'Thriller,  Psychological,  Romance,  Drama': 1,
#          'Mystery,  Horror,  Drama,  Supernatural': 1,
#          'Action,  Comedy,  Martial Arts,  Sci-Fi': 1,
#          'Comedy,  Sitcom,  Political': 1,
#          'Thriller,  Mystery,  Romance': 1,
#          'Life,  Political': 1,
#          'Thriller,  Mystery,  Sci-Fi,  Medical': 1,
#          'Action,  Adventure,  Tokusatsu,  Sci-Fi': 1,
#          'Food,  Romance,  Youth,  Drama': 1,
#          'Romance,  Supernatural': 1,
#          'Sci-Fi': 1,
#          'Thriller,  Romance': 1,
#          'Historical,  Romance,  Drama': 1,
#          'Thriller,  Historical,  Mystery,  Horror': 1,
#          'Sci-Fi,  Fantasy': 1,
#          'Romance,  Youth,  Sci-Fi,  Fantasy': 1,
#          'Historical,  Romance,  Drama,  Fantasy': 1,
#          'Romance,  Youth,  Drama,  Supernatural': 1,
#          'Youth,  Fantasy': 1,
#          'Mystery,  Romance,  Youth,  Supernatural': 1,
#          'Thriller,  Romance,  Drama,  Fantasy': 1,
#          'Psychological,  Life,  Fantasy,  Supernatural': 1,
#          'Comedy,  Romance,  Youth,  Sitcom': 1,
#          'Comedy,  Life,  Drama,  Sports': 1,
#          'Adventure,  Thriller,  Mystery,  Fantasy': 1,
#          'Historical,  Romance,  Life,  Drama': 1,
#          'Drama,  Documentary': 1,
#          'Action,  Historical,  Drama,  Fantasy': 1,
#          'Romance,  Drama,  Family,  Sitcom': 1,
#          'Thriller,  Mystery,  Psychological,  Sci-Fi': 1,
#          'Music,  Historical,  Romance,  Fantasy': 1,
#          'Comedy,  Law,  Crime,  Drama': 1,
#          'Thriller,  Mystery,  Fantasy,  Political': 1,
#          'Action,  Historical,  Romance,  Political': 1,
#          'Adventure,  Youth': 1,
#          'Mystery,  Romance,  Drama': 1,
#          'Historical,  Comedy,  Fantasy': 1,
#          'Action,  Horror,  Drama,  Sci-Fi': 1,
#          'Historical,  Comedy,  Romance,  Fantasy': 1,
#          'Mystery,  Business,  Comedy,  Life': 1,
#          'Thriller,  Mystery,  Crime,  Fantasy': 1,
#          'Action,  Mystery,  Drama,  Supernatural': 1,
#          'Life,  Fantasy': 1,
#          'Youth,  Sci-Fi': 1,
#          'Comedy,  Life,  Drama,  Melodrama': 1,
#          'Mystery,  Comedy,  Law,  Melodrama': 1,
#          'Mystery,  Romance,  Sci-Fi,  Supernatural': 1,
#          'Music,  Romance,  Drama,  Fantasy': 1,
#          'Military,  Thriller,  Mystery,  Horror': 1,
#          'Business,  Comedy,  Romance,  Youth': 1,
#          'Thriller,  Horror,  Romance,  Fantasy': 1,
#          'Music,  Comedy,  Romance,  Melodrama': 1,
#          'Thriller,  Mystery,  Romance,  Crime': 1,
#          'Thriller,  Psychological,  Drama': 1,
#          'Mystery,  Horror,  Comedy,  Supernatural': 1,
#          'Romance,  Life,  Drama,  Fantasy': 1,
#          'Mystery,  Crime,  Youth,  Drama': 1,
#          'Business,  Romance,  Drama,  Family': 1,
#          'Thriller,  Romance,  Melodrama': 1,
#          'Adventure,  Life,  Fantasy,  Melodrama': 1,
#          'Music,  Romance,  Drama,  Melodrama': 1,
#          'Comedy,  Youth,  Sci-Fi': 1,
#          'Mystery,  Sci-Fi,  Fantasy,  Melodrama': 1,
#          'Music,  Life,  Youth': 1,
#          'Thriller,  Horror,  Psychological,  Supernatural': 1,
#          'Food,  Youth': 1,
#          'Thriller,  Romance,  Crime,  Melodrama': 1,
#          'Thriller,  Mystery,  Comedy,  Melodrama': 1,
#          'Mystery,  Life,  Drama': 1,
#          'Mystery,  Psychological,  Crime,  Drama': 1,
#          'Comedy,  Romance,  Drama,  Political': 1,
#          'Action,  Business,  Comedy,  Romance': 1,
#          'Adventure,  Comedy,  Romance': 1,
#          'Mystery,  Comedy,  Drama,  Fantasy': 1,
#          'Comedy,  Youth,  Drama,  Sitcom': 1,
#          'Psychological,  Crime,  Youth,  Drama': 1,
#          'Music,  Romance,  Supernatural': 1,
#          'Drama,  Supernatural': 1,
#          'Action,  Thriller,  Crime,  Sci-Fi': 1,
#          'Thriller,  Historical,  Horror,  Supernatural': 1,
#          'Drama,  Family,  Melodrama,  Supernatural': 1,
#          'Mystery,  Comedy,  Law,  Romance': 1,
#          'Action,  Comedy,  Crime,  Sitcom': 1,
#          'Romance,  Drama,  Sci-Fi,  Melodrama': 1,
#          'Business,  Psychological,  Romance,  Medical': 1,
#          'Thriller,  Mystery,  Psychological,  Supernatural': 1,
#          'Food,  Romance,  Drama,  Fantasy': 1,
#          'Mystery,  Business,  Drama,  Political': 1,
#          'Romance,  Drama,  Medical,  Melodrama': 1,
#          'Mystery,  Law,  Life,  Drama': 1,
#          'Mystery,  Comedy,  Supernatural': 1,
#          'Military,  Comedy,  Romance,  Political': 1,
#          'Drama,  Sports,  Melodrama': 1,
#          'Adventure,  Mystery,  Fantasy': 1,
#          'Mystery,  Comedy,  Sci-Fi': 1,
#          'Romance,  Life,  Medical,  Melodrama': 1,
#          'Mystery,  Comedy,  Romance,  Melodrama': 1,
#          'Thriller,  Mystery,  Comedy,  Crime': 1,
#          'Drama,  Political': 1,
#          'Food,  Fantasy': 1,
#          'Action,  Historical,  Romance,  Drama': 1,
#          'Food,  Drama,  Fantasy': 1,
#          'Mystery,  Comedy,  Romance,  Sci-Fi': 1,
#          'Life,  Family': 1,
#          'Thriller,  Horror,  Psychological,  Drama': 1,
#          'Comedy,  Drama,  Political': 1,
#          'Comedy,  Law,  Romance,  Fantasy': 1,
#          'Tokusatsu': 1,
#          'Music,  Comedy,  Drama,  Fantasy': 1,
#          'Mystery,  Romance,  Life,  Medical': 1,
#          'Thriller,  Mystery,  Law,  Youth': 1,
#          'Thriller,  Mystery,  Drama,  Medical': 1,
#          'Life,  Drama,  Sports': 1,
#          'Life,  Drama,  Family': 1,
#          'Comedy,  Romance,  Supernatural,  Sitcom': 1,
#          'Mystery,  Law,  Drama,  Medical': 1,
#          'Drama,  Fantasy': 1,
#          'Action,  Historical,  Romance,  Medical': 1,
#          'Historical,  Romance,  War,  Political': 1,
#          'Action,  Business,  Comedy,  Drama': 1,
#          'Thriller,  Mystery,  Life,  Melodrama': 1,
#          'Comedy,  Romance,  Crime,  Political': 1,
#          'Fantasy': 1,
#          'Business,  Romance,  Life,  Melodrama': 1,
#          'Thriller,  Law,  Crime,  Medical': 1,
#          'Comedy,  Romance,  Life,  Supernatural': 1,
#          'Comedy,  Drama,  Supernatural': 1,
#          'Business,  Life': 1,
#          'Action,  Adventure,  Historical,  Political': 1,
#          'Food,  Romance,  Youth': 1,
#          'Mystery,  Business,  Law,  Romance': 1,
#          'Thriller,  Historical,  Horror,  Political': 1,
#          'Business,  Comedy,  Drama,  Fantasy': 1,
#          'Romance,  Drama,  Medical,  Fantasy': 1,
#          'Action,  Thriller,  Romance,  Sci-Fi': 1,
#          'Business,  Romance,  Life,  Political': 1,
#          'Music,  Historical,  Romance,  Melodrama': 1,
#          'Thriller,  Horror,  Romance,  Drama': 1,
#          'Romance,  Life,  Family,  Melodrama': 1,
#          'Mystery,  Psychological,  Drama': 1,
#          'Action,  Thriller,  Mystery,  Romance': 1,
#          'Mystery,  Medical': 1,
#          'Comedy,  Youth,  Supernatural': 1,
#          'Romance,  Life,  Melodrama': 1,
#          'Food,  Comedy,  Romance,  Supernatural': 1,
#          'Mystery,  Drama,  Fantasy': 1,
#          'Music,  Business,  Comedy': 1,
#          'Adventure,  Romance,  Drama,  Sports': 1,
#          'Documentary': 1,
#          'Action,  Life,  Drama,  Medical': 1,
#          'Action,  Crime,  Youth': 1,
#          'Mystery,  Romance,  Melodrama': 1,
#          'Thriller,  Psychological,  Drama,  Medical': 1,
#          'Comedy,  Romance,  Medical': 1,
#          'Military,  Comedy,  Romance,  Drama': 1,
#          'Mystery,  Psychological,  Romance,  Melodrama': 1,
#          'Military,  Historical,  Romance,  Melodrama': 1,
#          'Business,  Romance,  Melodrama': 1,
#          'Action,  Mystery,  Psychological,  Comedy': 1,
#          'Comedy,  Romance,  Sci-Fi,  Fantasy': 1,
#          'Music,  Romance,  Fantasy,  Melodrama': 1,
#          'Thriller,  Mystery,  Law,  Medical': 1,
#          'Action,  Thriller,  Law,  Romance': 1,
#          'Action,  Business,  Law,  Drama': 1,
#          'Mystery,  Fantasy': 1,
#          'Thriller,  Mystery,  Comedy,  Law': 1,
#          'Romance,  Medical,  Melodrama': 1,
#          'Mystery,  Melodrama': 1,
#          'Mystery,  Romance,  Sci-Fi': 1,
#          'Thriller,  Mystery,  Medical': 1,
#          'Music,  Comedy,  Romance,  Life': 1,
#          'Thriller,  Mystery,  Psychological,  Melodrama': 1,
#          'Mystery,  Business,  Comedy,  Romance': 1,
#          'Youth,  Fantasy,  Supernatural': 1,
#          'Action,  Mystery,  Crime,  Political': 1,
#          'Psychological,  Romance,  Melodrama': 1,
#          'Life,  Melodrama': 1,
#          'Romance,  Drama,  Fantasy,  Melodrama': 1,
#          'Action,  Thriller,  Mystery,  Business': 1,
#          'Action,  Romance,  Crime,  Drama': 1,
#          'Comedy,  Crime,  Life,  Drama': 1,
#          'Business,  Law,  Romance,  Melodrama': 1,
#          'Mystery,  Psychological,  Romance,  Supernatural': 1,
#          'Comedy,  Drama,  Fantasy,  Supernatural': 1,
#          'Adventure,  Comedy,  Romance,  Life': 1,
#          'Action,  Thriller,  Mystery': 1,
#          'Action,  Adventure,  Thriller,  Drama': 1,
#          'Action,  Comedy,  Romance': 1,
#          'Mystery,  Romance,  Fantasy': 1,
#          'Comedy,  Sci-Fi,  Fantasy': 1,
#          'Mystery,  Drama,  Political': 1,
#          'Food,  Romance,  Drama,  Family': 1,
#          'Mystery,  Comedy,  Romance,  Life': 1,
#          'Music,  Comedy,  Life': 1,
#          'Action,  Mystery,  Drama': 1,
#          'Comedy,  Romance,  Youth,  Sci-Fi': 1,
#          'Comedy,  Youth,  Fantasy': 1,
#          'Historical,  Comedy,  Romance': 1,
#          'Food,  Historical,  Drama': 1,
#          'Business,  Comedy,  Romance,  Sports': 1,
#          'Action,  Thriller,  Mystery,  Law': 1,
#          'Food,  Comedy,  Drama,  Fantasy': 1,
#          'Life,  Youth,  Drama,  Melodrama': 1,
#          'Action,  Thriller,  Comedy,  Romance': 1,
#          'Comedy,  Romance,  Supernatural,  Political': 1,
#          'Action,  Tokusatsu,  Sci-Fi': 1,
#          'Thriller,  Law,  Romance,  Drama': 1,
#          'Drama,  Fantasy,  Supernatural': 1,
#          'Thriller,  Mystery,  Sci-Fi,  Fantasy': 1,
#          'Thriller,  Psychological,  Romance,  Melodrama': 1,
#          'Thriller,  Comedy,  Romance': 1,
#          'Music,  Drama,  Family,  Melodrama': 1,
#          'Medical': 1,
#          'Action,  Comedy,  Romance,  Supernatural': 1,
#          'Action,  Thriller,  Historical,  Romance': 1,
#          'Historical,  Mystery,  Romance,  Melodrama': 1,
#          'Business,  Comedy,  Crime,  Drama': 1,
#          'Adventure,  Mystery,  Comedy,  Drama': 1,
#          'Psychological,  Romance,  Supernatural': 1,
#          'Law,  Youth,  Drama': 1,
#          'Music,  Comedy,  Romance,  Supernatural': 1,
#          'Adventure,  Comedy': 1,
#          'Food,  Romance,  Fantasy': 1,
#          'Food,  Romance,  Drama,  Melodrama': 1,
#          'Comedy,  Life,  Sitcom': 1,
#          'Adventure,  Comedy,  Fantasy': 1,
#          'Action,  Mystery,  Sci-Fi,  Fantasy': 1,
#          'Action,  Thriller,  Psychological,  Romance': 1,
#          'Historical,  Documentary': 1,
#          'Historical,  Romance,  Fantasy,  Melodrama': 1,
#          'Law,  Romance,  Drama,  Melodrama': 1,
#          'Food,  Mystery,  Comedy,  Romance': 1,
#          'Business,  Drama': 1,
#          'Law,  Romance,  Drama,  Political': 1,
#          'Comedy,  Romance,  Youth,  Supernatural': 1,
#          'Comedy,  Romance,  Documentary': 1,
#          'Mystery,  Psychological,  Romance,  Medical': 1,
#          'Mystery,  Comedy,  Crime,  Drama': 1,
#          'Thriller,  Mystery,  Romance,  Life': 1,
#          'Thriller,  Mystery,  Horror,  Drama': 1,
#          'Romance,  Drama,  Sci-Fi': 1,
#          'Business,  Comedy,  Life': 1,
#          'Comedy,  Drama,  Family,  Melodrama': 1,
#          'Life,  Drama,  Family,  Melodrama': 1,
#          'Historical,  Law,  Drama,  Melodrama': 1,
#          'Food,  Mystery,  Drama,  Melodrama': 1,
#          'Music,  Business,  Comedy,  Drama': 1,
#          'Mystery,  Comedy,  Law': 1,
#          'Action,  Historical,  Comedy,  Drama': 1,
#          'Business,  Romance,  Crime,  Melodrama': 1,
#          'Thriller,  Business,  Romance,  Drama': 1,
#          'Action,  Comedy,  Romance,  Melodrama': 1,
#          'Comedy,  Romance,  Drama,  Fantasy,  Supernatural': 1,
#          'Action,  Romance,  Drama,  Supernatural': 1,
#          'Psychological,  Romance,  Life,  Drama': 1,
#          'Food,  Drama': 1,
#          'Thriller,  Mystery,  Law,  Romance': 1,
#          'Life,  Supernatural': 1,
#          'Comedy,  Law,  Romance,  Life': 1,
#          'Action,  Historical,  Drama,  Political': 1,
#          'Romance,  Youth,  Drama,  Sports': 1,
#          'Historical,  Business,  Melodrama,  Political': 1,
#          'Historical,  Romance,  Drama,  Family,  Melodrama': 1,
#          'Crime,  Life,  Drama': 1,
#          'Mystery,  Drama,  Supernatural': 1,
#          'Music,  Comedy,  Fantasy': 1,
#          'Action,  Romance,  Drama,  Medical': 1,
#          'Action,  Mystery': 1,
#          'Comedy,  Life,  Supernatural': 1,
#          'Historical,  Mystery,  Romance,  Fantasy': 1,
#          'Thriller,  Comedy,  Romance,  Supernatural': 1,
#          'Action,  Mystery,  Romance,  Crime': 1,
#          'Comedy,  Supernatural': 1,
#          'Mystery,  Romance,  Supernatural': 1,
#          'Historical,  Romance,  Drama,  Family': 1,
#          'Law,  Drama,  Family': 1,
#          'Action,  Romance,  Medical,  Supernatural': 1,
#          'Mystery,  Law,  Drama,  Melodrama': 1,
#          'Historical,  Romance,  Supernatural,  Political': 1,
#          'Thriller,  Romance,  Crime,  Political': 1})
